# %%
attempt = 0
max_attempt = 5
while attempt <= max_attempt:
    user_pasword = input("enter a pasword")
    attempt += 1
    lenght = len(user_pasword) >= 8
    number = any(char.isdigit() for char in user_pasword)
    upper =  any(char.isupper() for char in user_pasword)
    condition = sum([lenght, number, upper])
    if condition == 0:
        strength = "very weak"
    elif condition == 1:
        strength = "weak"
    elif condition == 2:
        strength = "moderate"
    else:
        strength = "strong"
    remaining = max_attempt - attempt
    print(f"feedback: {strength}")
    print(f"remaining_attempt: {remaining}")
    if condition == 3:
        print(f"You created a strong password!")
        print(f"AI Training Level: Beginner → Intermediate")
        break
        if attempt == max_attempt and conditions != 3:
            print(f"Final Result: Password is not strong enough.")
