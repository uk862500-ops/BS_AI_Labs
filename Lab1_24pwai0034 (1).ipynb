# %%
## part 1
name = "ubaid ullah"
age = 19
city = "lower dir samer bagh"
print(name)
print(age)
print(city)
# Out:
# ubaid ullah
# 19
# lower dir samer bagh

# %%
##Create 2 number variables:
num1 = 6
num2 = 7
sum = num1+num2
print(sum)
subtraction = num1-num2
print(subtraction)
multiplication = num1 * num2
print(multiplication)
# Out:
# 13
# -1
# 42

# %%
##PART 2 – Input and Output
##Take input from user:
name = input("insert your name")
age = int(input("your age"))
print(f"hello {name}, you are {age} year old")
# Out:
# insert your name ubaid
# your age 19
# hello ubaid, you are 19 year old

# %%
##Take input of two numbers from user
num1 = int(input("enter first digit"))
num2 =  int(input("enter second digit"))
add = num1+num2
sub = num1-num2
print(f"addition = {add}")
print(f"subtraction = {sub}")
# Out:
# enter first digit 7
# enter second digit 8
# addition = 15
# subtraction = -1

# %%
##PART 3 – Comments

##ask for user input name
#ask for age
## add two number num1 and num2

# %%
##PART 4- TYPE CHECK
name = "ubaid"
age = 19
values = 5.5
print(type(name))
print(type(age))
print(type(values))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#PART 5 – Data Type
##Ask age
age = int(input("how old are you"))
##print after 10 years
age = age+10
print(f" your age after 10 year is {age} ")
#Ask marks
marks = int(input("what is your marks"))
##print average
average = marks/2
print(f" your marks = {marks}, average{average}")
# Out:
# how old are you 19
#  your age after 10 year is 29
# what is your marks 80
#  your marks = 80, average40.0

# %%
##Task 1 – Even or Odd
num = int(input("enter a number"))
##Check if number is even or odd
if num%2 == 0:
    print(f"{num}, is even")
else:
    print(f"{num}, is odd")
# Out:
# enter a number 6
# 6, is even

# %%
##Task 2 – Grade System

marks = int(input("enter your marks"))

if marks >= 80:
    print(f" your marks = {marks}, your grade is A")
elif marks >=70:
    print(f" your marks = {marks}, your grade is B")
elif marks >= 60:
    print(f"your marks = {marks}, your grade is C")
else:
    print(f" your marks is {marks}, you are fail")
# Out:
# enter your marks 70
#  your marks = 70, your grade is B

# %%
##Task 3 – Voting Eligibility
##Take age from user
age = int(input("enter your age"))
if age >=18:
    print("you can vote")
else:
    print("not eligible")
# Out:
# enter your age 19
# you can vote

# %%
##Task 4 – Print Numbers (For Loop)
##Print numbers from 1 to 10
number = (10)
for number in range(1,10):
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
##Task 5 – Multiplication Table
##Take number from user
number = int(input("enter a number"))
for number in range(1,11):
    table = number*i
    print(f"{number} * {i} = {table}")
# Out:
# enter a number 6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 number = int(input("enter a number"))
#       4 for number in range(1,11):
# ----> 5     table = number*i
#       6     print(f"{number} * {i} = {table}")
#
# NameError: name 'i' is not defined

# %%
##Task 6 – Sum of First 10 Numbers
sum = 0
for number in range(1,10):
    sum += number
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
# First we create password variable (important!)
password = ""   # empty string so while loop can start

while password != "admin1234":
    password = input("Enter your password: ")
    
    if password == "admin1234":
        print("Access screen")
    else:
        print("Incorrect password, try again!")

print("You are now logged in!")
# Out:
# Enter your password:  admin1234
# Access screen
# You are now logged in!

# %%
##Task 8 – function
##• Write a function average(a,b,c)
def average(a,b,c):
    avg = (a+b+c)/3
    return avg
result = average(10,20,30)
print("the average is: ", result)
# Out:
# the average is:  20.0
