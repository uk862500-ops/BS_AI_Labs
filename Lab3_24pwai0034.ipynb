# %%
#task 1
def welcome_message():
    print("welcom to python")
welcome_message()
# Out:
# welcom to python

# %%
#task2
def sum(a,b):
    return a+b
print(sum(6,8))
# Out:
# 14

# %%
# task3
def functionA():
    print("inside function A")
    def functionB():
        print("inside function B")
    functionB()
functionA()
# Out:
# inside function A
# inside function B

# %%
# task4
def greet(name = "student"):
    print(f"hello {name}")
greet()
# Out:
# hello student

# %%
#task5
x = 10
def my_function():
    print("global x: ", x)
    y = 20
    print("local y: ", y)
my_function()
# try out function
print(x)
# try in function always error
# Out:
# global x:  10
# local y:  20
# 10

# %%
def total_number(*number):
    # Now this will use the built-in Python sum()
    total = sum(number) 
    return total

result = total_number(1, 2, 3, 4, 5)
print(f"total = {result}")

# %%
#task
def student_info(name,**data):
    print(f"student:, {name}")
    for key, value in data.items():
        print(f"{key}: {value}")
student_info("ubaid", reg_no = 34,age = 20, address = "lower dir")
# Out:
# student:, ubaid
# reg_no: 34
# age: 20
# address: lower dir

# %%
#task8
square = lambda x: x **2
print(square(10))
# Out:
# 100

# %%
#task9
number = [1,2,3,4,5]
square_list = list(map(lambda x: x ** 2, number))
print(square_list)
# Out:
# [1, 4, 9, 16, 25]

# %%
#task10
marks = [45,67,82,30,90,55]
number = 50
filtered_marks = list(filter(lambda x: x>50, marks))
print(filtered_marks)
# Out:
# [67, 82, 90, 55]

# %%
#Mini,-project: "AI number Guessing Game lite"
import random
secret = random.randint(1,50)
while guess != secret:
    guess = int(input("try agin,enter your guess"))
    if guess < secret:
        print(f"too low {guess}")
    elif guess > secret:
        print(f" too high {guess}")
    elif guess == secret:
        print(f"you win in x attempts! Al training level: Beginner - intermediate")
    else:
        print("try agin next time")
# Out:
# try agin,enter your guess 8
# too low 8
# try agin,enter your guess 20
# too low 20
# try agin,enter your guess 40
#  too high 40
# try agin,enter your guess 3
# too low 3
# try agin,enter your guess 30
#  too high 30
# try agin,enter your guess 25
# too low 25
# try agin,enter your guess 28
#  too high 28
# try agin,enter your guess 27
# you win in x attempts! Al training level: Beginner - intermediate
